# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext lab_black

# %%
import os
from pyspark.sql import Column, DataFrame, SparkSession, functions as F, Window


spark = (
    SparkSession.builder.master("local[*]")
    .appName("fitviz")
    .config("spark.driver.memory", "8g")
    .config(
        "spark.jars.packages",
        "io.delta:delta-core_2.12:0.7.0,org.apache.hadoop:hadoop-aws:2.7.7",
    )
    .config(
        "spark.delta.logStore.class",
        "org.apache.spark.sql.delta.storage.S3SingleDriverLogStore",
    )
    .config("spark.hadoop.fs.s3a.access.key", os.getenv("AWS_ACCESS_KEY_ID", None))
    .config("spark.hadoop.fs.s3a.secret.key", os.getenv("AWS_SECRET_ACCESS_KEY", None))
    .getOrCreate()
)

from delta.tables import DeltaTable

# %%
import os
import datetime
import altair as alt
import numpy as np
import pandas as pd

from pathlib import Path


from fitviz import FitFile

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 500)

# %%
# %%time
bolt = FitFile("fit_files/Who_Dares_Bolt.fit", reprocess=True)
sufferfest = FitFile("fit_files/Who_Dares_Sufferfest.fit", reprocess=True)
whoop = FitFile("fit_files/Who_Dares_WHOOP.fit", reprocess=True)
bolt_w_gps = FitFile("fit_files/Bolt_GPS.fit", reprocess=True)
# Out:
# 2020-12-01 18:54:36.123 | INFO     | fitviz.FitFile:_process_fit2csv:83 - Removing /Users/johnmdonich/fitvis-tmp/Who_Dares_Bolt-18677721.csv for reprocessing
# 2020-12-01 18:54:36.635 | INFO     | fitviz.FitFile:_process_fit2csv:98 - FIT CSV Tool - Protocol 2.0 Profile 21.40 Release
# FIT binary file fit_files/Who_Dares_Bolt.fit decoded to /Users/johnmdonich/fitvis-tmp/Who_Dares_Bolt-18677721*.csv files.
#
# 2020-12-01 18:54:37.064 | INFO     | fitviz.FitFile:_process_fit2csv:83 - Removing /Users/johnmdonich/fitvis-tmp/Who_Dares_Sufferfest-18674217.csv for reprocessing
# 2020-12-01 18:54:37.480 | INFO     | fitviz.FitFile:_process_fit2csv:98 - FIT CSV Tool - Protocol 2.0 Profile 21.40 Release
# FIT binary file fit_files/Who_Dares_Sufferfest.fit decoded to /Users/johnmdonich/fitvis-tmp/Who_Dares_Sufferfest-18674217*.csv files.
#
# 2020-12-01 18:54:37.858 | INFO     | fitviz.FitFile:_process_fit2csv:83 - Removing /Users/johnmdonich/fitvis-tmp/Who_Dares_WHOOP-18677504.csv for reprocessing
# 2020-12-01 18:54:38.156 | INFO     | fitviz.FitFile:_process_fit2csv:98 - FIT CSV Tool - Protocol 2.0 Profile 21.40 Release
# FIT binary file fit_files/Who_Dares_WHOOP.fit decoded to /Users/johnmdonich/fitvis-tmp/Who_Dares_WHOOP-18677504*.csv files.
#
# 2020-12-01 18:54:38.455 | INFO     | fitviz.FitFile:_process_fit2csv:83 - Removing /Users/johnmdonich/fitvis-tmp/Bolt_GPS-18757466.csv for reprocessing
# 2020-12-01 18:54:39.656 | INFO     | fitviz.FitFile:_process_fit2csv:98 - FIT CSV Tool - Protocol 2.0 Profile 21.40 Release
# FIT binary file fit_files/Bolt_GPS.fit decoded to /Users/johnmdonich/fitvis-tmp/Bolt_GPS-18757466*.csv files.
# CPU times: user 222 ms, sys: 80.5 ms, total: 302 ms
# Wall time: 4.03 s

# %%
attr = "file"
bolt.long_df.where(F.col("message") == attr).orderBy("timestamp", "message_id").show(32)
sufferfest.long_df.where(F.col("message") == attr).orderBy("timestamp").show()
whoop.long_df.where(F.col("message") == attr).orderBy("timestamp").show()
# Out:
# +-----------+------------+-------+-----------+-------------------+-------------+-------------+-----+
# |record_type|local number|message| message_id|          timestamp|        field|        value|units|
# +-----------+------------+-------+-----------+-------------------+-------------+-------------+-----+
# |       Data|           0|   file|-1665041827|2020-11-25 13:48:44| time_created|    975264524| null|
# |       Data|           0|   file|-1665041827|2020-11-25 13:48:44| manufacturer|wahoo_fitness| null|
# |       Data|           0|   file|-1665041827|2020-11-25 13:48:44|serial_number|   3338297344| null|
# |       Data|           0|   file|-1665041827|2020-11-25 13:48:44|         file|     activity| null|
# |       Data|           0|   file|-1665041827|2020-11-25 13:48:44|      product|           31| null|
# +-----------+------------+-------+-----------+-------------------+-------------+-------------+-----+
#
# +-----------+------------+-------+----------+-------------------+-------------+--------------+-----+
# |record_type|local number|message|message_id|          timestamp|        field|         value|units|
# +-----------+------------+-------+----------+-------------------+-------------+--------------+-----+
# |       Data|           0|   file|-564207281|2020-11-25 13:48:03|serial_number|         12345| null|
# |       Data|           0|   file|-564207281|2020-11-25 13:48:03|         file|      activity| null|
# |       Data|           0|   file|-564207281|2020-11-25 13:48:03| manufacturer|the_sufferfest| null|
# |       Data|           0|   file|-564207281|2020-11-25 13:48:03|      product|          1231| null|
# |       Data|           0|   file|-564207281|2020-11-25 13:48:03| time_created|     975264483| null|
# +-----------+------------+-------+----------+-------------------+-------------+--------------+-----+
#
# +-----------+------------+-------+----------+---------+-------------+--------+-----+
# |record_type|local number|message|message_id|timestamp|        field|   value|units|
# +-----------+------------+-------+----------+---------+-------------+--------+-----+
# |       Data|           0|   file| 878986544|     null|         file|activity| null|
# |       Data|           0|   file| 878986544|     null| manufacturer|   whoop| null|
# |       Data|           0|   file| 878986544|     null|      product|       3| null|
# |       Data|           0|   file| 878986544|     null|serial_number|   12345| null|
# +-----------+------------+-------+----------+---------+-------------+--------+-----+

# %%
sufferfest.long_df.where(F.col("message") == "record").select(
    "*", F.lit("N/A").alias("device")
).select("timestamp", "device", "field", "value", "units").orderBy("timestamp").show()
# Out:
# +-------------------+------+--------------+---------+-----+
# |          timestamp|device|         field|    value|units|
# +-------------------+------+--------------+---------+-----+
# |2020-11-25 13:48:03|   N/A|enhanced_speed|      0.0|  m/s|
# |2020-11-25 13:48:03|   N/A|      distance|      0.0|    m|
# |2020-11-25 13:48:03|   N/A|         power|        0|watts|
# |2020-11-25 13:48:03|   N/A|    heart_rate|       64|  bpm|
# |2020-11-25 13:48:03|   N/A|         speed|      0.0|  m/s|
# |2020-11-25 13:48:03|   N/A|       cadence|        0|  rpm|
# |2020-11-25 13:48:03|   N/A|     timestamp|975264483|    s|
# |2020-11-25 13:48:04|   N/A|    heart_rate|       64|  bpm|
# |2020-11-25 13:48:04|   N/A|         power|        0|watts|
# |2020-11-25 13:48:04|   N/A|enhanced_speed|      0.0|  m/s|
# |2020-11-25 13:48:04|   N/A|     timestamp|975264484|    s|
# |2020-11-25 13:48:04|   N/A|       cadence|        0|  rpm|
# |2020-11-25 13:48:04|   N/A|      distance|      0.0|    m|
# |2020-11-25 13:48:04|   N/A|         speed|      0.0|  m/s|
# |2020-11-25 13:48:05|   N/A|     timestamp|975264485|    s|
# |2020-11-25 13:48:05|   N/A|       cadence|        0|  rpm|
# |2020-11-25 13:48:05|   N/A|         speed|    0.626|  m/s|
# |2020-11-25 13:48:05|   N/A|         power|       15|watts|
# |2020-11-25 13:48:05|   N/A|    heart_rate|       64|  bpm|
# |2020-11-25 13:48:05|   N/A|      distance|      0.0|    m|
# +-------------------+------+--------------+---------+-----+
# only showing top 20 rows

# %%
# bolt_w_gps.long_df.groupBy("field").agg(F.count("*")).show(100)

# %%
# %%time
bolt_pdf = bolt_w_gps.long_df.where(F.col("message") == "record").toPandas()
# Out:
# CPU times: user 27.5 s, sys: 373 ms, total: 27.9 s
# Wall time: 30.8 s

# %%
# sufferfest.csv_df.show(50)

# %%
sufferfest.csv_df.show(truncate=False)
# Out:
# +-----------+------------+-----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |record_type|local number|message    |fields                                                                                                                                                              |
# +-----------+------------+-----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |Data       |0           |file_id    |[[type, 4,], [manufacturer, 282,], [product, 1231,], [serial_number, 12345,], [time_created, 975264483,]]                                                           |
# |Data       |0           |device_info|[[timestamp, 975267819, s], [battery_status, 2,]]                                                                                                                   |
# |Data       |0           |record     |[[timestamp, 975264483, s], [power, 0, watts], [speed, 0.0, m/s], [distance, 0.0, m], [cadence, 0, rpm], [heart_rate, 64, bpm], [enhanced_speed, 0.0, m/s]]         |
# |Data       |0           |record     |[[timestamp, 975264484, s], [power, 0, watts], [speed, 0.0, m/s], [distance, 0.0, m], [cadence, 0, rpm], [heart_rate, 64, bpm], [enhanced_speed, 0.0, m/s]]         |
# |Data       |0           |record     |[[timestamp, 975264485, s], [power, 15, watts], [speed, 0.626, m/s], [distance, 0.0, m], [cadence, 0, rpm], [heart_rate, 64, bpm], [enhanced_speed, 0.626, m/s]]    |
# |Data       |0           |record     |[[timestamp, 975264486, s], [power, 37, watts], [speed, 0.626, m/s], [distance, 1.0, m], [cadence, 0, rpm], [heart_rate, 65, bpm], [enhanced_speed, 0.626, m/s]]    |
# |Data       |0           |record     |[[timestamp, 975264487, s], [power, 49, watts], [speed, 1.207, m/s], [distance, 2.0, m], [cadence, 0, rpm], [heart_rate, 65, bpm], [enhanced_speed, 1.207, m/s]]    |
# |Data       |0           |record     |[[timestamp, 975264488, s], [power, 115, watts], [speed, 1.699, m/s], [distance, 4.0, m], [cadence, 0, rpm], [heart_rate, 71, bpm], [enhanced_speed, 1.699, m/s]]   |
# |Data       |0           |record     |[[timestamp, 975264489, s], [power, 138, watts], [speed, 2.369, m/s], [distance, 6.0, m], [cadence, 26, rpm], [heart_rate, 72, bpm], [enhanced_speed, 2.369, m/s]]  |
# |Data       |0           |record     |[[timestamp, 975264490, s], [power, 149, watts], [speed, 3.085, m/s], [distance, 9.0, m], [cadence, 40, rpm], [heart_rate, 74, bpm], [enhanced_speed, 3.085, m/s]]  |
# |Data       |0           |record     |[[timestamp, 975264491, s], [power, 149, watts], [speed, 3.576, m/s], [distance, 13.0, m], [cadence, 67, rpm], [heart_rate, 77, bpm], [enhanced_speed, 3.576, m/s]] |
# |Data       |0           |record     |[[timestamp, 975264492, s], [power, 149, watts], [speed, 4.023, m/s], [distance, 17.0, m], [cadence, 68, rpm], [heart_rate, 79, bpm], [enhanced_speed, 4.023, m/s]] |
# |Data       |0           |record     |[[timestamp, 975264493, s], [power, 149, watts], [speed, 4.426, m/s], [distance, 21.0, m], [cadence, 69, rpm], [heart_rate, 88, bpm], [enhanced_speed, 4.426, m/s]] |
# |Data       |0           |record     |[[timestamp, 975264494, s], [power, 149, watts], [speed, 4.739, m/s], [distance, 26.0, m], [cadence, 71, rpm], [heart_rate, 90, bpm], [enhanced_speed, 4.739, m/s]] |
# |Data       |0           |record     |[[timestamp, 975264495, s], [power, 149, watts], [speed, 5.052, m/s], [distance, 31.0, m], [cadence, 72, rpm], [heart_rate, 94, bpm], [enhanced_speed, 5.052, m/s]] |
# |Data       |0           |record     |[[timestamp, 975264496, s], [power, 149, watts], [speed, 5.32, m/s], [distance, 36.0, m], [cadence, 73, rpm], [heart_rate, 96, bpm], [enhanced_speed, 5.32, m/s]]   |
# |Data       |0           |record     |[[timestamp, 975264497, s], [power, 148, watts], [speed, 5.543, m/s], [distance, 42.0, m], [cadence, 75, rpm], [heart_rate, 98, bpm], [enhanced_speed, 5.543, m/s]] |
# |Data       |0           |record     |[[timestamp, 975264498, s], [power, 148, watts], [speed, 5.722, m/s], [distance, 48.0, m], [cadence, 76, rpm], [heart_rate, 100, bpm], [enhanced_speed, 5.722, m/s]]|
# |Data       |0           |record     |[[timestamp, 975264499, s], [power, 148, watts], [speed, 5.946, m/s], [distance, 53.0, m], [cadence, 76, rpm], [heart_rate, 100, bpm], [enhanced_speed, 5.946, m/s]]|
# |Data       |0           |record     |[[timestamp, 975264500, s], [power, 148, watts], [speed, 6.124, m/s], [distance, 60.0, m], [cadence, 77, rpm], [heart_rate, 100, bpm], [enhanced_speed, 6.124, m/s]]|
# +-----------+------------+-----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
bolt.sort_values(["timestamp", "message_id"]).head(25)
# Out:
#        record_type local number message  message_id           timestamp  \
# 39720         Data            0  record  1016102544 2020-08-30 12:48:10
# 51226         Data            0  record  1016102544 2020-08-30 12:48:10
# 170364        Data            0  record  1016102544 2020-08-30 12:48:10
# 192291        Data            0  record  1016102544 2020-08-30 12:48:10
# 338892        Data            0  record  1016102544 2020-08-30 12:48:10
# 8761          Data            0  record   765652872 2020-08-30 12:48:11
# 13571         Data            0  record   765652872 2020-08-30 12:48:11
# 78985         Data            0  record   765652872 2020-08-30 12:48:11
# 170366        Data            0  record   765652872 2020-08-30 12:48:11
# 218006        Data            0  record   765652872 2020-08-30 12:48:11
# 230823        Data            0  record   765652872 2020-08-30 12:48:11
# 268416        Data            0  record   765652872 2020-08-30 12:48:11
# 270711        Data            0  record   765652872 2020-08-30 12:48:11
# 338894        Data            0  record   765652872 2020-08-30 12:48:11
# 90537         Data            0  record  -648616945 2020-08-30 12:48:12
# 130721        Data            0  record  -648616945 2020-08-30 12:48:12
# 217884        Data            0  record  -648616945 2020-08-30 12:48:12
# 230822        Data            0  record  -648616945 2020-08-30 12:48:12
# 238184        Data            0  record  -648616945 2020-08-30 12:48:12
# 270598        Data            0  record  -648616945 2020-08-30 12:48:12
# 303551        Data            0  record  -648616945 2020-08-30 12:48:12
# 307561        Data            0  record  -648616945 2020-08-30 12:48:12
# 338893        Data            0  record  -648616945 2020-08-30 12:48:12
# 78986         Data            0  record   -16021481 2020-08-30 12:48:13
# 170368        Data            0  record   -16021481 2020-08-30 12:48:13
#
#                  field      value    units
# 39720        timestamp  967740490        s
# 51226         distance        0.0        m
# 170364           speed      0.759      m/s
# 192291  enhanced_speed      0.759      m/s
# 338892      heart_rate         96      bpm
# 8761          distance       0.55        m
# 13571   enhanced_speed      0.794      m/s
# 78985        timestamp  967740491        s
# 170366           speed      0.794      m/s
# 218006           power          0    watts
# 230823        calories          0     kcal
# 268416     battery_soc       98.0  percent
# 270711         cadence          0      rpm
# 338894      heart_rate         96      bpm
# 90537         distance        1.1        m
# 130721       timestamp  967740492        s
# 217884           power          0    watts
# 230822        calories          0     kcal
# 238184  enhanced_speed      0.829      m/s
# 270598         cadence          0      rpm
# 303551           speed      0.829      m/s
# 307561     temperature         23        C
# 338893      heart_rate         96      bpm
# 78986        timestamp  967740493        s
# 170368           speed      0.864      m/s

# %%
bolt_w_gps.csv_df.count()
# Out:
# 22028

# %%
# %%time
sufferfest_records = sufferfest.long_df.where(F.col("message") == "record").toPandas()
# Out:
# CPU times: user 1.65 s, sys: 20.7 ms, total: 1.67 s
# Wall time: 2.12 s

# %%
sufferfest_records.shape
# Out:
# (22750, 8)

# %%
sufferfest_records.field.unique()
# Out:
# array(['cadence', 'distance', 'enhanced_speed', 'heart_rate', 'power',
#        'speed', 'timestamp'], dtype=object)

# %%
import altair as alt

alt.Chart(sufferfest_records[sufferfest_records.field == "power"]).mark_bar().encode(
    x="timestamp:T", y="value:Q"
)
# Out:
# alt.Chart(...)

# %%
sufferfest.long_df.rdd.getNumPartitions()
# Out:
# 8

# %%
# bolt.long_df.where(F.col("message") == "device_info").toPandas()

# %%
whoop.long_df.groupBy("message").agg(F.count("message").alias("records")).show()
# Out:
# +-------+-------+
# |message|records|
# +-------+-------+
# |   file|      4|
# |session|     11|
# | record|   5397|
# +-------+-------+

# %%
bolt.long_df.show()
# Out:
# +-----------+------------+-----------+-----------+-------------------+-------------------+----------+-------+
# |record_type|local number|    message| message_id|          timestamp|              field|     value|  units|
# +-----------+------------+-----------+-----------+-------------------+-------------------+----------+-------+
# |       Data|           0|device_info|  462092124|2020-11-25 14:01:49|antplus_device_type|bike_power|   null|
# |       Data|           0|device_info| 2098285500|2020-11-25 14:41:49|antplus_device_type|bike_power|   null|
# |       Data|           0|device_info| -835262131|2020-11-25 14:31:49|antplus_device_type|bike_power|   null|
# |       Data|           0|device_info| -257609311|2020-11-25 13:48:44|antplus_device_type|bike_power|   null|
# |       Data|           0|device_info|  682523891|2020-11-25 14:11:49|antplus_device_type|bike_power|   null|
# |       Data|           0|device_info|  708168908|2020-11-25 14:21:49|antplus_device_type|bike_power|   null|
# |       Data|           0|device_info|  897265531|2020-11-25 13:51:49|antplus_device_type|bike_power|   null|
# |       Data|           0|    session| 1536422595|2020-11-25 14:43:38|    avg_temperature|        21|      C|
# |       Data|           0|        lap| 1724068441|2020-11-25 14:43:38|    avg_temperature|        21|      C|
# |       Data|           0|     record|-1039436397|2020-11-25 14:18:49|        battery_soc|      53.0|percent|
# |       Data|           0|     record|-1166632801|2020-11-25 14:24:45|            cadence|       104|    rpm|
# |       Data|           0|     record| -416900774|2020-11-25 14:23:48|            cadence|       104|    rpm|
# |       Data|           0|     record| -864147655|2020-11-25 14:24:58|            cadence|       104|    rpm|
# |       Data|           0|     record| -409127585|2020-11-25 13:57:26|            cadence|       104|    rpm|
# |       Data|           0|     record|  752786859|2020-11-25 14:15:25|            cadence|       104|    rpm|
# |       Data|           0|     record| 1656145203|2020-11-25 14:06:07|            cadence|       104|    rpm|
# |       Data|           0|     record| 1938287556|2020-11-25 14:24:43|            cadence|       104|    rpm|
# |       Data|           0|     record|-2128256843|2020-11-25 14:20:32|            cadence|       104|    rpm|
# |       Data|           0|     record| 1598392905|2020-11-25 14:09:39|            cadence|       104|    rpm|
# |       Data|           0|     record|-1603359136|2020-11-25 14:24:36|            cadence|       110|    rpm|
# +-----------+------------+-----------+-----------+-------------------+-------------------+----------+-------+
# only showing top 20 rows

# %%
from fitSDK import PROFILE
